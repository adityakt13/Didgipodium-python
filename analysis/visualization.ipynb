# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
years = np.arange(2000, 2010)
print(years)
population = np.random.randint(10,100, 10)
print(population)
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009]
# [65 87 93 15 60 19 86 53 56 35]

# %%
plt.bar(years, population, color = {'red', 'hotpink'})
plt.title("Population fluctuation")
# Out:
# Text(0.5, 1.0, 'Population fluctuation')
